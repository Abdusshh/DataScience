# %% [markdown]
# # FOOD RECIPES DATA SCIENCE PROJECT
# This project is focused on the [food_recipes](https://www.kaggle.com/datasets/sarthak71/food-recipes) dataset.
# Main goal of this project is to find meaningful insights from the data and showcase them in a clear and understandable way.

# %% [markdown]
# ### Before We Start
# Importing pandas and loading the dataset.

# %%
! pip install pandas 

import pandas as pd
# Out:
# Requirement already satisfied: pandas in c:\users\abdul\appdata\local\programs\python\python310\lib\site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\abdul\appdata\roaming\python\python310\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\abdul\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\abdul\appdata\local\programs\python\python310\lib\site-packages (from pandas) (1.24.2)
# Requirement already satisfied: six>=1.5 in c:\users\abdul\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
path = "food_recipes.csv"
df = pd.read_csv(path)
df.head()
# Out:
#                                         recipe_title  \
# 0  Roasted Peppers And Mushroom Tortilla Pizza Re...
# 1  Thakkali Gotsu Recipe | Thakkali Curry | Spicy...
# 2               Spicy Grilled Pineapple Salsa Recipe
# 3     Karwar Style Dali Thoy Recipe - Toor dal Curry
# 4    Rajma Kofta In Milk And Poppy Seed Gravy Recipe
#
#                                                  url record_health  \
# 0  https://www.archanaskitchen.com/roasted-pepper...          good
# 1  https://www.archanaskitchen.com/tomato-gotsu-r...          good
# 2  https://www.archanaskitchen.com/spicy-grilled-...          good
# 3  https://www.archanaskitchen.com/dali-thoy-reci...          good
# 4  https://www.archanaskitchen.com/rajma-kofta-in...          good
#
#    vote_count    rating                                        description  \
# 0         434  4.958525   is a quicker version pizza to satisfy your cr...
# 1        3423  4.932223   also known as the   is a quick and easy to ma...
# 2        2091  4.945959  Spicy Grilled Pineapple Salsa is a simple reci...
# 3         990  4.888889  The   is a quintessential of Konkani dish whic...
# 4         345  4.828986  Koftas are traditional Indian recipes mostly w...
#
#                 cuisine     course                     diet prep_time  \
# 0               Mexican     Dinner               Vegetarian      15 M
# 1  South Indian Recipes      Lunch               Vegetarian      10 M
# 2               Mexican  Side Dish               Vegetarian      10 M
# 3     Coastal Karnataka  Side Dish  High Protein Vegetarian       5 M
# 4  North Indian Recipes  Side Dish  High Protein Vegetarian      20 M
#
#   cook_time                                        ingredients  \
# 0      15 M  Tortillas|Extra Virgin Olive Oil|Garlic|Mozzar...
# 1      20 M  Sesame (Gingelly) Oil|Mustard seeds (Rai/ Kadu...
# 2       0 M  Extra Virgin Olive Oil|Pineapple|White onion|R...
# 3      20 M  Arhar dal (Split Toor Dal)|Turmeric powder (Ha...
# 4      30 M  Rajma (Large Kidney Beans)|Cashew nuts|Sultana...
#
#                                         instructions             author  \
# 0  To begin making the Roasted Peppers And Mushro...  Divya Shivaraman
# 1  To begin making Tomato Gotsu Recipe/ Thakkali ...      Archana Doshi
# 2  To begin making the Spicy Grilled Pineapple Sa...  Archana's Kitchen
# 3  To prepare Karwar Style Dali Thoy Recipe (Toor...      Jyothi Rajesh
# 4  To begin making Rajma Kofta In Milk And Poppy ...        RUBY PATHAK
#
#                                                 tags              category
# 0  Party Food Recipes|Tea Party Recipes|Mushroom ...         Pizza Recipes
# 1  Vegetarian Recipes|Tomato Recipes|South Indian...  Indian Curry Recipes
# 2  Party Starter & Appetizer Recipes|Pineapple Re...       Mexican Recipes
# 3  Side Dish Recipes|South Indian Recipes|Indian ...  Indian Curry Recipes
# 4  Side Dish Recipes|Indian Lunch Recipes|Office ...         Kofta Recipes

# %% [markdown]
# ## Table of Contents
# 1. [Data Cleaning](#data_cleaning)
# 2. [Data Analysis and Visualization](#data_analysis_and_visualization)
# 3. [Conclusion of Research](#conclusion_of_research)
# 4. [Useful Functions For Users](#useful_functions_for_users)
# 5. [Creating an Interactive Dashboard](#creating_an_interactive_dashboard)

# %% [markdown]
# ### Data Cleaning <a class = "anchor" id="data_cleaning"></a>
# First, we need to clean the data. We will fill the missing values with the mean of the columns, fix some of the data types and remove unnecessary columns.
# We will also store the cleaned data in a new csv file.

# %%
# Drop the columns that are not required
# Urls, authors, tags and categories are not required for the analysis

# Let's see the different types of record_healt column
df['record_health'].groupby(df['record_health']).count()
# All of them are good, so we can drop this column

# Prep time and cook time are better off as sum of the two as total time so let's also drop them

new_df = df.drop(['url', 'record_health', 'author','tags','category','prep_time','cook_time'], axis='columns')
new_df.head()
# Out:
#                                         recipe_title  vote_count    rating  \
# 0  Roasted Peppers And Mushroom Tortilla Pizza Re...         434  4.958525
# 1  Thakkali Gotsu Recipe | Thakkali Curry | Spicy...        3423  4.932223
# 2               Spicy Grilled Pineapple Salsa Recipe        2091  4.945959
# 3     Karwar Style Dali Thoy Recipe - Toor dal Curry         990  4.888889
# 4    Rajma Kofta In Milk And Poppy Seed Gravy Recipe         345  4.828986
#
#                                          description               cuisine  \
# 0   is a quicker version pizza to satisfy your cr...               Mexican
# 1   also known as the   is a quick and easy to ma...  South Indian Recipes
# 2  Spicy Grilled Pineapple Salsa is a simple reci...               Mexican
# 3  The   is a quintessential of Konkani dish whic...     Coastal Karnataka
# 4  Koftas are traditional Indian recipes mostly w...  North Indian Recipes
#
#       course                     diet  \
# 0     Dinner               Vegetarian
# 1      Lunch               Vegetarian
# 2  Side Dish               Vegetarian
# 3  Side Dish  High Protein Vegetarian
# 4  Side Dish  High Protein Vegetarian
#
#                                          ingredients  \
# 0  Tortillas|Extra Virgin Olive Oil|Garlic|Mozzar...
# 1  Sesame (Gingelly) Oil|Mustard seeds (Rai/ Kadu...
# 2  Extra Virgin Olive Oil|Pineapple|White onion|R...
# 3  Arhar dal (Split Toor Dal)|Turmeric powder (Ha...
# 4  Rajma (Large Kidney Beans)|Cashew nuts|Sultana...
#
#                                         instructions
# 0  To begin making the Roasted Peppers And Mushro...
# 1  To begin making Tomato Gotsu Recipe/ Thakkali ...
# 2  To begin making the Spicy Grilled Pineapple Sa...
# 3  To prepare Karwar Style Dali Thoy Recipe (Toor...
# 4  To begin making Rajma Kofta In Milk And Poppy ...

# %%
# 1. count the number of NaN values in time columns
num_nan = df['prep_time'].isna().sum()
print(num_nan)

# 2. for now replace the NaN values in time columns with 0
df['prep_time'] = df['prep_time'].fillna(0)
df['cook_time'] = df['cook_time'].fillna(0)

print(df['prep_time'].dtypes)
print(df['cook_time'].dtypes)

# 3. convert the datatype of prep_time and cook_time from object to str
df['prep_time'] = df['prep_time'].astype(str)
df['cook_time'] = df['cook_time'].astype(str)

# 4. convert the datatype of prep_time and cook_time to int and extract the numbers from the string
new_df['prep_time'] = df['prep_time'].str.extract('(\d+)').astype(int)
new_df['cook_time'] = df['cook_time'].str.extract('(\d+)').astype(int)

print(new_df['prep_time'].mean())

# 5. change the 0 values in prep_time and cook_time to mean of the column
new_df['prep_time'] = new_df['prep_time'].replace(0, new_df['prep_time'].mean())
new_df['cook_time'] = new_df['cook_time'].replace(0, new_df['cook_time'].mean())

# 6. add a new column total_time
new_df['total_time'] = (new_df['prep_time'] + new_df['cook_time']).astype(int)

# 7. drop the prep_time and cook_time columns
new_df = new_df.drop(['prep_time', 'cook_time'], axis='columns')

new_df.head()
# Out:
# 30
# object
# object
# 28.82394805843426
#                                         recipe_title  vote_count    rating  \
# 0  Roasted Peppers And Mushroom Tortilla Pizza Re...         434  4.958525
# 1  Thakkali Gotsu Recipe | Thakkali Curry | Spicy...        3423  4.932223
# 2               Spicy Grilled Pineapple Salsa Recipe        2091  4.945959
# 3     Karwar Style Dali Thoy Recipe - Toor dal Curry         990  4.888889
# 4    Rajma Kofta In Milk And Poppy Seed Gravy Recipe         345  4.828986
#
#                                          description               cuisine  \
# 0   is a quicker version pizza to satisfy your cr...               Mexican
# 1   also known as the   is a quick and easy to ma...  South Indian Recipes
# 2  Spicy Grilled Pineapple Salsa is a simple reci...               Mexican
# 3  The   is a quintessential of Konkani dish whic...     Coastal Karnataka
# 4  Koftas are traditional Indian recipes mostly w...  North Indian Recipes
#
#       course                     diet  \
# 0     Dinner               Vegetarian
# 1      Lunch               Vegetarian
# 2  Side Dish               Vegetarian
# 3  Side Dish  High Protein Vegetarian
# 4  Side Dish  High Protein Vegetarian
#
#                                          ingredients  \
# 0  Tortillas|Extra Virgin Olive Oil|Garlic|Mozzar...
# 1  Sesame (Gingelly) Oil|Mustard seeds (Rai/ Kadu...
# 2  Extra Virgin Olive Oil|Pineapple|White onion|R...
# 3  Arhar dal (Split Toor Dal)|Turmeric powder (Ha...
# 4  Rajma (Large Kidney Beans)|Cashew nuts|Sultana...
#
#                                         instructions  total_time
# 0  To begin making the Roasted Peppers And Mushro...          30
# 1  To begin making Tomato Gotsu Recipe/ Thakkali ...          30
# 2  To begin making the Spicy Grilled Pineapple Sa...          41
# 3  To prepare Karwar Style Dali Thoy Recipe (Toor...          25
# 4  To begin making Rajma Kofta In Milk And Poppy ...          50

# %%
# Let's check the total_time column for any absurd values
new_df['total_time'].describe()

# Let's find the super high and low values
new_df.loc[new_df['total_time'] > 800]
new_df.loc[new_df['total_time'] < 5]

# Let's see some of the instructions for the super high and low values
#new_df.loc[6207, 'instructions']

# Since we have only one Swedish dish and it breaks our data, let's drop it
new_df = new_df.drop([6207], axis='rows')

# %% [markdown]
# Most of the time values are not errors but the food takes a long time to dry, soak, marinate, etc.

# %%
# There is an error in this Nepalese dish
new_df.loc[4917, 'total_time'] = new_df['total_time'].mean()
new_df.loc[new_df['cuisine'] == 'Nepalese']

# Convert the total_time column to int
new_df['total_time'] = new_df['total_time'].astype(int)


# Save the cleaned data to a new csv file
#new_df.to_csv('cleaned_food_recipes.csv', index=False)

# %% [markdown]
# ### Data Analysis and Visualization <a class = "anchor" id="data_analysis_and_visualization"></a>
# Now that we have cleaned the data, we can start analyzing it. We will start by looking at the total time to cook certain cuisines and diets and then we will look at the most popular cuisines and diets.

# %% [markdown]
# #### Before We Start
# Importing bokeh and loading the cleaned dataset.

# %%
! pip install bokeh
# Out:
# Requirement already satisfied: bokeh in c:\users\abdul\appdata\local\programs\python\python310\lib\site-packages (3.1.1)
# Requirement already satisfied: pandas>=1.2 in c:\users\abdul\appdata\local\programs\python\python310\lib\site-packages (from bokeh) (1.5.3)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\abdul\appdata\local\programs\python\python310\lib\site-packages (from bokeh) (9.4.0)
# Requirement already satisfied: contourpy>=1 in c:\users\abdul\appdata\local\programs\python\python310\lib\site-packages (from bokeh) (1.0.7)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\abdul\appdata\local\programs\python\python310\lib\site-packages (from bokeh) (3.1.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\abdul\appdata\local\programs\python\python310\lib\site-packages (from bokeh) (2023.2.0)
# Requirement already satisfied: packaging>=16.8 in c:\users\abdul\appdata\roaming\python\python310\site-packages (from bokeh) (23.0)
# Requirement already satisfied: numpy>=1.16 in c:\users\abdul\appdata\local\programs\python\python310\lib\site-packages (from bokeh) (1.24.2)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\abdul\appdata\local\programs\python\python310\lib\site-packages (from bokeh) (6.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\abdul\appdata\roaming\python\python310\site-packages (from bokeh) (6.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\abdul\appdata\local\programs\python\python310\lib\site-packages (from Jinja2>=2.9->bokeh) (2.1.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\abdul\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.2->bokeh) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\abdul\appdata\roaming\python\python310\site-packages (from pandas>=1.2->bokeh) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\abdul\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.1->pandas>=1.2->bokeh) (1.16.0)
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import ColumnDataSource, HoverTool
from bokeh.palettes import Category20c
from bokeh.transform import factor_cmap
from bokeh.palettes import Turbo256

current_df = pd.read_csv('cleaned_food_recipes.csv')

# %% [markdown]
# Let's find out the average cooking time of every cuisine

# %%
# 1. group the dataframe by cuisine
grouped_df = current_df.groupby('cuisine')
grouped_df.head()

# 2. find the average of total_time for every cuisine
avg_time = grouped_df['total_time'].mean().round()
print(avg_time)

# 3. sort the values in descending order
avg_time = avg_time.sort_values(ascending=False)

output_notebook()

# Visualize the data using Bokeh
# create a ColumnDataSource object
source = ColumnDataSource(avg_time.to_frame())

# create a figure object
fig_cuisine_time = figure(x_range=avg_time.index.values, height=500, width=1500, title="Average time taken to cook every cuisine")


# add axis labels
fig_cuisine_time.xaxis.axis_label = "Cuisine"
fig_cuisine_time.yaxis.axis_label = "Average time taken to cook (in minutes)"

# create a palette of colors because we have many cuisines we use Turbo256
my_palette = Turbo256[::3]

# create a bar chart
fig_cuisine_time.vbar(x='cuisine', top='total_time', width=0.9, source=source,
         line_color='white', fill_color=factor_cmap('cuisine', palette=my_palette, factors=avg_time.index.values))

# set the y axis range
fig_cuisine_time.y_range.start = 0

# set the x axis labels to appear at 45 degree angle
fig_cuisine_time.xaxis.major_label_orientation = 1

# add a hover tool
fig_cuisine_time.add_tools(HoverTool(tooltips=[("Cuisine", "@cuisine"), ("Average time taken to cook", "@total_time")]))

# show the plot
show(fig_cuisine_time)
# Out:
# cuisine
# Afghan                       45.0
# African                      52.0
# American                     78.0
# Andhra                       49.0
# Arab                         55.0
#                              ...
# Thai                         44.0
# Udupi                        47.0
# Uttar Pradesh                38.0
# Uttarakhand-North Kumaon     92.0
# Vietnamese                   77.0
# Name: total_time, Length: 76, dtype: float64
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="eed9eb89-cd04-4aaf-a17d-bf2e9b3fe36f">Loading BokehJS ...</span>
#     </div>
#   <div id="d60fd22f-fe12-43d6-b50b-d04f20069af2" data-root-id="p1004" style="display: contents;"></div>

# %% [markdown]
# Let's find out the average cooking time of every diet

# %%
# 1. group the dataframe by diet
grouped_df_diet = current_df.groupby('diet')
grouped_df_diet.head()

# 2. find the average of total_time for every diet
avg_time_diet = grouped_df_diet['total_time'].mean().round(2)
print(avg_time_diet)

# 3. sort the values in descending order
avg_time_diet = avg_time_diet.sort_values(ascending=False)

output_notebook()

# create a ColumnDataSource object
source = ColumnDataSource(avg_time_diet.to_frame())

# create a figure object
fig_diet_time = figure(x_range=avg_time_diet.index.values, height=500, width=750, title="Average time taken to cook every diet")

# add axis labels
fig_diet_time.xaxis.axis_label = "Diet"
fig_diet_time.yaxis.axis_label = "Average time taken to cook (in minutes)"

# create a palette of colors because we have less than 20 diets we use Category20c
my_palette = Category20c[20]

# create a bar chart
fig_diet_time.vbar(x='diet', top='total_time', width=0.9, source=source,
            line_color='white', fill_color=factor_cmap('diet', palette=my_palette, factors=avg_time_diet.index.values))

# set the y axis range
fig_diet_time.y_range.start = 0

# set the x axis labels to appear at 45 degree angle
fig_diet_time.xaxis.major_label_orientation = 1

# add a hover tool
fig_diet_time.add_tools(HoverTool(tooltips=[("Diet", "@diet"), ("Average time taken to cook", "@total_time")]))

# show the plot
show(fig_diet_time)
# Out:
# diet
# Diabetic Friendly               67.94
# Eggetarian                      70.07
# Gluten Free                     94.82
# High Protein Non Vegetarian     52.33
# High Protein Vegetarian         72.08
# No Onion No Garlic (Sattvic)    44.10
# Non Vegeterian                  70.79
# Sugar Free Diet                 47.73
# Vegan                           73.14
# Vegetarian                      58.76
# Name: total_time, dtype: float64
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c458c20f-40e9-47f9-bbe1-d2a139df9c8e">Loading BokehJS ...</span>
#     </div>
#   <div id="fd1a27b8-1b4e-4783-8bfd-9b3b69022f3e" data-root-id="p1144" style="display: contents;"></div>

# %% [markdown]
# Let's find out the most liked cuisine

# %%
# 0. multiply ratings by 20 only once to scale it between 0 and 100 
mid_df = current_df.copy()

mid_df['rating'] = current_df['rating'] * 20 

# 1. group the dataframe by cuisine
grouped_df_likes = mid_df.groupby('cuisine')
grouped_df_likes.head()

# 2. find the average rating for every cuisine
avg_likes = grouped_df_likes['rating'].mean()
print(avg_likes)

# 3. sort the values in descending order
avg_likes = avg_likes.sort_values(ascending=False)

output_notebook()

# create a ColumnDataSource object
source = ColumnDataSource(avg_likes.to_frame())

# create a figure object
fig_cuisine_rating = figure(x_range=avg_likes.index.values, height=500, width=1500, title="Average rating of every cuisine")

# add axis labels
fig_cuisine_rating.xaxis.axis_label = "Cuisine"
fig_cuisine_rating.yaxis.axis_label = "Average rating"

# create a palette of colors because we have many cuisines we use Turbo256
my_palette = Turbo256[::3]

# create a bar chart
fig_cuisine_rating.vbar(x='cuisine', top='rating', width=0.9, source=source, 
            line_color='white', fill_color=factor_cmap('cuisine', palette=my_palette, factors=avg_likes.index.values))

# set the y axis range
fig_cuisine_rating.y_range.start = 90

# set the x axis labels to appear at 45 degree angle
fig_cuisine_rating.xaxis.major_label_orientation = 1

# add a hover tool
fig_cuisine_rating.add_tools(HoverTool(tooltips=[("Cuisine", "@cuisine"), ("Average rating", "@rating")]))

# show the plot
show(fig_cuisine_rating)
# Out:
# cuisine
# Afghan                       93.470089
# African                      98.326757
# American                     98.386360
# Andhra                       97.940153
# Arab                         97.644716
#                                ...
# Thai                         98.213016
# Udupi                        97.871597
# Uttar Pradesh                97.612161
# Uttarakhand-North Kumaon     98.906171
# Vietnamese                   98.623637
# Name: rating, Length: 76, dtype: float64
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="f2ad5322-2d6c-4592-bef6-9301d9055f74">Loading BokehJS ...</span>
#     </div>
#   <div id="df1f538a-f08f-4fce-9653-9f9a2e00ef16" data-root-id="p1297" style="display: contents;"></div>

# %% [markdown]
# Let's find out the most liked diet

# %%
# 1. group the dataframe by diet
grouped_df_likes_diet = mid_df.groupby('diet')
grouped_df_likes_diet.head()

# 2. find the average rating for every diet
avg_likes_diet = grouped_df_likes_diet['rating'].mean()
print(avg_likes_diet)

# 3. sort the values in descending order
avg_likes_diet = avg_likes_diet.sort_values(ascending=False)

output_notebook()

# create a ColumnDataSource object
source = ColumnDataSource(avg_likes_diet.to_frame())

# create a figure object   
fig_diet_rating = figure(x_range=avg_likes_diet.index.values, height=500, width=750, title="Average rating of every diet")

# add axis labels
fig_diet_rating.xaxis.axis_label = "Diet"
fig_diet_rating.yaxis.axis_label = "Average rating"

# create a palette of colors because we have less than 20 diets we use Category20c
my_palette = Category20c[20]

# create a bar chart
fig_diet_rating.vbar(x='diet', top='rating', width=0.9, source=source,
            line_color='white', fill_color=factor_cmap('diet', palette=my_palette, factors=avg_likes_diet.index.values))

# set the y axis range
fig_diet_rating.y_range.start = 97

# set the x axis labels to appear at 45 degree angle
fig_diet_rating.xaxis.major_label_orientation = 1

# add a hover tool
fig_diet_rating.add_tools(HoverTool(tooltips=[("Diet", "@diet"), ("Average rating", "@rating")]))

# show the plot
show(fig_diet_rating)
# Out:
# diet
# Diabetic Friendly               97.816502
# Eggetarian                      97.725072
# Gluten Free                     97.460345
# High Protein Non Vegetarian     98.117434
# High Protein Vegetarian         97.824175
# No Onion No Garlic (Sattvic)    97.515257
# Non Vegeterian                  98.022794
# Sugar Free Diet                 97.722362
# Vegan                           97.443330
# Vegetarian                      97.750647
# Name: rating, dtype: float64
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="e39595fe-6f64-4413-805a-397eff1b7f3a">Loading BokehJS ...</span>
#     </div>
#   <div id="f855e9de-88c2-4028-867b-d0849198ddfd" data-root-id="p1463" style="display: contents;"></div>

# %% [markdown]
# Let's see all of the above in one graph

# %%
# Let's create a dashboard to visualize the data using Bokeh Dashboard
# import the necessary libraries
from bokeh.io import show
from bokeh.layouts import row, column
from bokeh.io import curdoc

# create a dashboard layout
layout = row(column(fig_cuisine_time, fig_cuisine_rating, row(fig_diet_time, fig_diet_rating)))

# add the layout to curdoc
curdoc().add_root(layout)

# Show the dashboard
show(layout)
# Out:
#   <div id="a3b3ab32-10db-42d7-96bd-9b11e9339b09" data-root-id="p1641" style="display: contents;"></div>

# %% [markdown]
# ### Conclusion of Research <a class = "anchor" id="conclusion_of_research"></a>
# Let's summarize what we have found out.

# %% [markdown]
# #### Why is average cooking time of diets and cuisines important?
#
# The data on the average preparation times of different cuisines and diets is a valuable resource for anyone who is interested in exploring new flavors, managing their time effectively, and making healthy and delicious meals. This data can help you plan your meals with ease, and ensure that you have enough time to prepare your food while adhering to your dietary needs.
#
# One of the most significant advantages of this data is that it helps you understand the level of difficulty associated with preparing dishes from different cuisines and diets. This can be especially helpful for those who are new to a particular cuisine or diet, as it can help them identify dishes that are easier to prepare and gradually work their way up to more complex recipes. Additionally, knowing the average preparation time of different cuisines and diets can help you identify recipes that can be prepared quickly, without compromising on flavor or nutrition.
#
# Another important benefit of this data is that it can help you explore new cuisines and flavors with ease. By identifying recipes with shorter preparation times, you can start experimenting with new ingredients and techniques, without feeling overwhelmed or intimidated by the process. This can be particularly useful for those who are looking to expand their culinary horizons, but may not have a lot of time to spend in the kitchen.
#
# In conclusion, the data on the average preparation times of different cuisines and diets is a valuable tool for anyone who is interested in making healthy and delicious meals while managing their time effectively. This data can help you plan your meals, explore new cuisines and flavors, and ensure that you are making the most of your time in the kitchen.

# %% [markdown]
# #### Why is average rating of cuisines and diets important?
#
# The average user rating of certain cuisines or diets is another important piece of data that can be incredibly useful for those interested in exploring new flavors and cuisines. By knowing the average rating of different cuisines or diets, you can get a sense of which dishes are particularly popular and highly regarded by others. This can help you identify recipes that are likely to be delicious, and that will appeal to your own personal tastes and preferences.
#
# Additionally, the average user rating of certain cuisines or diets can help you discover new recipes and dishes that you may not have otherwise considered. By looking for highly rated recipes in a particular cuisine or diet, you can expand your culinary horizons and explore new flavors and ingredients that you may not have tried before.
#
# Another important benefit of knowing the average user rating of certain cuisines or diets is that it can help you avoid recipes that are likely to be disappointing or not worth your time and effort. By looking for recipes with high ratings, you can be more confident that you are investing your time and resources into a dish that is likely to be delicious and well-received by your family and friends.
#
# In conclusion, the average user rating of certain cuisines or diets is a valuable piece of data that can help you discover new recipes, explore new flavors, and avoid recipes that are likely to be disappointing. Whether you are a seasoned cook or a novice in the kitchen, this data can help you make the most of your culinary adventures and ensure that every meal you prepare is delicious and satisfying.

# %% [markdown]
# ### Useful Functions For Users <a class = "anchor" id="useful_functions_for_users"></a>
# Here are some useful functions for users to use.

# %%
# We'll use the same data as before

df = pd.read_csv('cleaned_food_recipes.csv')

df.head()
# Out:
#                                         recipe_title  vote_count    rating  \
# 0  Roasted Peppers And Mushroom Tortilla Pizza Re...         434  4.958525
# 1  Thakkali Gotsu Recipe | Thakkali Curry | Spicy...        3423  4.932223
# 2               Spicy Grilled Pineapple Salsa Recipe        2091  4.945959
# 3     Karwar Style Dali Thoy Recipe - Toor dal Curry         990  4.888889
# 4    Rajma Kofta In Milk And Poppy Seed Gravy Recipe         345  4.828986
#
#                                          description               cuisine  \
# 0   is a quicker version pizza to satisfy your cr...               Mexican
# 1   also known as the   is a quick and easy to ma...  South Indian Recipes
# 2  Spicy Grilled Pineapple Salsa is a simple reci...               Mexican
# 3  The   is a quintessential of Konkani dish whic...     Coastal Karnataka
# 4  Koftas are traditional Indian recipes mostly w...  North Indian Recipes
#
#       course                     diet  \
# 0     Dinner               Vegetarian
# 1      Lunch               Vegetarian
# 2  Side Dish               Vegetarian
# 3  Side Dish  High Protein Vegetarian
# 4  Side Dish  High Protein Vegetarian
#
#                                          ingredients  \
# 0  Tortillas|Extra Virgin Olive Oil|Garlic|Mozzar...
# 1  Sesame (Gingelly) Oil|Mustard seeds (Rai/ Kadu...
# 2  Extra Virgin Olive Oil|Pineapple|White onion|R...
# 3  Arhar dal (Split Toor Dal)|Turmeric powder (Ha...
# 4  Rajma (Large Kidney Beans)|Cashew nuts|Sultana...
#
#                                         instructions  total_time
# 0  To begin making the Roasted Peppers And Mushro...          30
# 1  To begin making Tomato Gotsu Recipe/ Thakkali ...          30
# 2  To begin making the Spicy Grilled Pineapple Sa...          41
# 3  To prepare Karwar Style Dali Thoy Recipe (Toor...          25
# 4  To begin making Rajma Kofta In Milk And Poppy ...          50

# %% [markdown]
# #### Get Recipes with Certain Ingredients
# A function that will take in a list of ingredients and returns a list of recipes that contain those ingredients.

# %%
# Let's write a function that will take in a list of ingredients and return a list of recipes that contain those ingredients

# Find all nan values in the ingredients column
#print(df[df['ingredients'].isnull()])

# We'll need to replace the nan values with an empty string
df['ingredients'] = df['ingredients'].fillna('')

def get_recipes_with_ingredients(ingredients):
    
    # if len(ingredients) == 0, then the user didn't enter any ingredients
    if len(ingredients) == 0:
         return "You didn't enter any ingredients!"

    # We'll get a list of all the recipes that contain each ingredient
    recipes = []
    for ingredient in ingredients.split(' '):

        # convert the ingredient to lowercase
        ingredient = ingredient.lower()
        # capitalize the ingredient
        ingredient = ingredient.capitalize()
        # strip the ingredient of any leading or trailing spaces
        ingredient = ingredient.strip()

        # print(df[df['ingredients'].str.contains(ingredient)]['recipe_title'].tolist())
        recipes.append(df[df['ingredients'].str.contains(ingredient)]['recipe_title'].tolist())
        
    # We'll find the intersection of all the lists
    recipes = set(recipes[0]).intersection(*recipes)
    
    return recipes

# Let's try it out

get_recipes_with_ingredients(['Oil', 'Salt', 'Meat'])
# Out:
# ['Roasted Peppers And Mushroom Tortilla Pizza Recipe', 'Thakkali Gotsu Recipe | Thakkali Curry | Spicy & Tangy Tomato Gravy', 'Spicy Grilled Pineapple Salsa Recipe', 'Barnyard Millet Mushroom Biryani Recipe', 'Mexican Green Sauce Recipe ', 'Schezwan Style Chinese Veg Samosa Recipe - Roz Ka Khana with Figaro Olive Oil', 'Cheesy Rice Poppers Recipe', 'Goan Sorak Curry Recipe', 'Toffee Banana Recipe (Classic Chinese Dessert)', 'Coorg Style Kumbala Curry Recipe (Pumpkin Sabzi)', 'Kurkuri Bhindi And Onion Masala Recipe', 'Kerala Cherupayar Curry Recipe (Green Moong and Yellow Moong Dal Recipe)', 'Kela Matar ki Sabzi Recipe - Raw Banana Green Peas Stir Fry', 'Creamy Chicken Pesto Spaghetti Pasta Recipe', 'Hyderabadi Bagare Tamatar (Spiced, Tossed Tomato Curry)', 'Eggplant Rolls Recipe', 'Kodava Pacche Baale Barthad- Raw Banana Stir Fry', 'Lebanese Chickpea Falafel Recipe - Healthy Non Fried Recipe', 'Chettinad Pakora Curry Recipe', 'Eerulli Palya Recipe - Vengaya Poriyal Recipe', 'Karwar NKGSB Style Bharli Vangi Recipe - Brinjal Curry', 'Polenta Pizza With Vegetables Recipe', 'Vegetarian Sago Dumpling Recipe', 'Mooga Gathi (Sprouted Moong In Coconut Paste) Recipe', 'Grilled Tofu Satay Recipe With Peanut Dipping Sauce', 'Roasted Peppers & Cheese Crostini Recipe', 'Goan Kaju Curry Recipe (Spicy Goan Cashew Nut Curry)', 'Udupi Style Ash Gourd Coconut Curry Recipe ', 'Methi Bajra Poori Recipe', "Moongphali Bhindi Sabzi Recipe - Lady's Finger Peanut Stir Fry", 'Nargisi Kofta Curry Recipe - Spicy Scotched Egg Curry', 'Asian Style Tofu in Spicy Orange Sauce Recipe', 'Hesarukalu Bele Kosambari Recipe | Tangy Sprouted Green Moong Dal Salad', 'Goan Style Mushroom Vindaloo Recipe', 'Goan Mushroom Xacuti Recipe', 'Eggless Whole Wheat Plum Cake Recipe | Christmas Plum Cake', 'Pita Topped With Oven Roasted Cauliflower, Basil Avocado Sauce Recipe', 'Mangalore Cucumber Chana Dal Subzi Recipe ', 'Moroccan Chickpeas Stew Recipe ', 'Babru Recipe (Himachali Black Gram Stuffed Bread)', 'Urulai Kizhangu Masiyal Recipe (Potatoes in a Tangy lemon and Ginger Gravy)', 'Arabian Chicken Mandi Recipe -Yemeni Style Rice & Chicken', 'Moong Dal Ghughra Recipe (Gujiya/ Karanji)', 'Mixed Vegetable Handi Recipe', 'Stuffed Mushrooms With Spinach & Parmesan Recipe', 'Chenai Kizhangu Masiyal-South Indian Style Yam Masiyal', 'Punjabi Bhindi Kadhi Recipe - Roasted Okra In Yogurt Curry', 'Tamil Nadu Style Potato Masiyal Recipe (South Indian Style Aloo Masala)', 'Goan Bimbla Uddamethi Recipe', 'Mangalorean Manoli Bheeja Upkari Recipe - Ivy Gourd & Cashew Sabzi', 'Chilli Chicken Cheese Quesadilla Recipe ', 'Malwani Pumpkin And Raw Mango Curry Recipe', 'Vegan Kofta Curry Recipe', 'Muttai Podimas Recipe - Chettinad Egg Scramble ', 'Khakhra Vegetable Pizza Recipe', 'Chicken Manchurian Dry Recipe ', 'Thai Pineapple Vegetarian Curry Recipe', ' Beet Apple Salad Recipe with Apple Cider Vinaigrette', 'Kerala Style Varutharacha Mutta Curry Recipe', 'Chicken Spinach Cheese Balls Recipe', 'Mexican Corn Salsa Recipe', 'Broccoli and Mushroom Stir Fry Recipe ', 'Harissa Roasted Carrot Pizza With Pomegranate Sauce & Greek Yogurt Recipe', 'Smoked Vegetarian Spanish Rice Recipe', 'Thai Style Curried Corn Fritters Recipe', 'Mushroom Thoran Recipe-Kerala Style Mushroom Sabzi', 'Broccoli Egg Bhurji Recipe', 'Karwar Style Valval Recipe (Mixed Vegetables In Coconut Milk)', 'Spicy Roasted Pumpkin Carrot Soup Recipe', 'Kerala Style Vendakka Pachadi Recipe - Roasted Bhindi Coconut Raita', 'Andhra Style Pindi Miriyam Recipe ', 'Kerala Style Brinjal Curry Recipe | Spicy Eggplant Curry in Coconut Milk', 'Chenakayi Erissery Recipe - Yam Erissery', 'Chicken Yakitori Recipe - Japanese Chicken Skewers ', 'Kadalai Puli Kuzhambu With Mangalore Cucumber & Drumstick Recipe', ' Tamil Nadu Style Poo Kosu Poriyal - Pepper Garlic Cauliflower Poriyal Recipe', 'Oriya Style Ambila Recipe - Sweet & Spicy Mixed Vegetable Sabzi', 'Karnataka Style Orange Peels Curry Recipe', 'Banana Bread With Chocolate Chips And Walnut  ...
# ['Thakkali Gotsu Recipe | Thakkali Curry | Spicy & Tangy Tomato Gravy', 'Spicy Grilled Pineapple Salsa Recipe', 'Karwar Style Dali Thoy Recipe - Toor dal Curry', 'Rajma Kofta In Milk And Poppy Seed Gravy Recipe', 'Barnyard Millet Mushroom Biryani Recipe', 'Mexican Green Sauce Recipe ', 'Karnataka Style Avarekalu Chitranna Recipe (Field Beans Tossed With Lemon Rice)', 'Schezwan Style Chinese Veg Samosa Recipe - Roz Ka Khana with Figaro Olive Oil', 'Pineapple Upside Down Cake Recipe', 'Matar Butter Masala Recipe', 'Cheesy Rice Poppers Recipe', 'Savory Shrimps On Skillet Recipe', 'Goan Sorak Curry Recipe', 'Mango Tomato Bean Salsa Recipe', 'Coorg Style Kumbala Curry Recipe (Pumpkin Sabzi)', 'Kurkuri Bhindi And Onion Masala Recipe', 'Kerala Cherupayar Curry Recipe (Green Moong and Yellow Moong Dal Recipe)', 'Kela Matar ki Sabzi Recipe - Raw Banana Green Peas Stir Fry', 'Creamy Chicken Pesto Spaghetti Pasta Recipe', 'Hyderabadi Bagare Tamatar (Spiced, Tossed Tomato Curry)', 'Eggplant Rolls Recipe', 'Beans And Carrot Masala Pulav With Black Eyed Beans Recipe', 'Chettinad Kathirikai Chops Recipe - Brinjal Curry for Biryani', 'Kodava Pacche Baale Barthad- Raw Banana Stir Fry', 'Lebanese Chickpea Falafel Recipe - Healthy Non Fried Recipe', 'Drumstick Leaves Ragi Roti Recipe - Moringa Millet Flat Bread', 'Chettinad Pakora Curry Recipe', 'Eerulli Palya Recipe - Vengaya Poriyal Recipe', 'Karwar NKGSB Style Bharli Vangi Recipe - Brinjal Curry', 'Polenta Pizza With Vegetables Recipe', 'Eggless Buttermilk Cinnamon Rolls Recipe', 'Homemade Mole Sauce Recipe', 'Mexican Omelette Recipe with Avocado Salsa ', 'Spicy Pressure Cooker Mutton Curry Recipe ', 'Mysore Style Avarekalu Rasam Recipe ', 'Roasted Peppers & Cheese Crostini Recipe', 'Goan Kaju Curry Recipe (Spicy Goan Cashew Nut Curry)', 'Udupi Style Ash Gourd Coconut Curry Recipe ', 'Methi Bajra Poori Recipe', "Moongphali Bhindi Sabzi Recipe - Lady's Finger Peanut Stir Fry", 'Nargisi Kofta Curry Recipe - Spicy Scotched Egg Curry', 'Asian Style Tofu in Spicy Orange Sauce Recipe', 'Hesarukalu Bele Kosambari Recipe | Tangy Sprouted Green Moong Dal Salad', 'Bendakaya Pulusu Recipe - Andhra Style Tangy Ladies Finger Curry', 'Peerkangai Thogayal Recipe | Ridge Gourd Peel Chutney | Beerakaya Pachadi', 'Goan Style Mushroom Vindaloo Recipe', 'Dhaba Style Dal Fry Recipe | Mixed Dal Tadka', 'Goan Mushroom Xacuti Recipe', 'Pita Topped With Oven Roasted Cauliflower, Basil Avocado Sauce Recipe', 'Chamadumpa Vepudu Recipe - Andhra Style Colocasia Stir Fry | Arbi Sabzi', 'Mangalore Cucumber Chana Dal Subzi Recipe ', 'Aloo Parwal Sabzi Recipe - A Classic Bengali Dish', 'Chapor Ghonto Recipe - Bengali Mix Vegetable With Lentils Patties', 'Delicious Skillet Roasted Fondant Potatoes Recipe', 'Moroccan Chickpeas Stew Recipe ', 'Babru Recipe (Himachali Black Gram Stuffed Bread)', 'Niramish Shobji Chapor Jhol - Bengali Style Vegetable Curry with Lentil Patties', 'Arabian Chicken Mandi Recipe -Yemeni Style Rice & Chicken', 'Moong Dal Ghughra Recipe (Gujiya/ Karanji)', 'Hyderabadi Khadi Masoor Dal Recipe - Hyderabadi Style Lentil Curry', 'Vanilla Dutch Baby Pancake Recipe', 'Goan Moolyacho Ross Recipe (Goan Radish Curry)', 'Gujarati Dabeli Recipe - Pav Buns With Spicy Mashed Potatoes', 'Mixed Vegetable Handi Recipe', 'Stuffed Mushrooms With Spinach & Parmesan Recipe', 'Chenai Kizhangu Masiyal-South Indian Style Yam Masiyal', 'Aam Panna Pani Puri Recipe ', 'Punjabi Bhindi Kadhi Recipe - Roasted Okra In Yogurt Curry', 'Tamil Nadu Style Potato Masiyal Recipe (South Indian Style Aloo Masala)', 'Goan Bimbla Uddamethi Recipe', 'Papaya Parsley Salad with Cheese Recipe', 'Mangalorean Manoli Bheeja Upkari Recipe - Ivy Gourd & Cashew Sabzi', 'Chilli Chicken Cheese Quesadilla Recipe ', 'Maharashtrian Kakdi Thalipeeth Recipe - Spiced Cucumber Flat Bread', 'Eggless Chocolate Mug Cake Recipe - Instant Microwave Cake', 'Vegan Kofta Curry Recipe', 'Muttai Podimas Recipe - Chettinad Egg Scramble ', 'Bathua Raita Recipe ', 'Szechwan  ...
# ['Spicy Pressure Cooker Mutton Curry Recipe ', 'Calicut Payyoli Chicken Fry Recipe', 'Meat Masala Stuffed Bharwa Baingan Recipe', 'Nepalese Mutton Curry Recipe', 'Calamari Roast Recipe (Kerala Style Squid)']
# {'Calicut Payyoli Chicken Fry Recipe', 'Nepalese Mutton Curry Recipe'}

# %% [markdown]
# #### Get Random Recipes Based on Diet
# Get 5 random recipes based on given diet

# %%
# random module will be used to generate a random number
import random

# %%
# Let's write a function that will take a string of preferred diet and return 5 random recipes that fit that diet

# Find all nan values in the diet column
#print(df[df['diet'].isnull()])

# We'll need to replace the nan values with an Unknown string
df['diet'] = df['diet'].fillna('Unknown')

# Let's change the No Onion No Garlic (Sattvic) diet to No Onion No Garlic to get rid of the parantheses because it will cause problems with regex
df["diet"] = df["diet"].replace("No Onion No Garlic (Sattvic)", "No Onion No Garlic")

def get_random_diet_recipes(diet, n=5):
    
    # if the diet is not in diets column, we'll return "Sorry, we don't have any recipes for the given diet"
    if diet not in df['diet'].unique():
        return "Sorry, we don't have any recipes for the given diet!"

    # We'll get a list of all the recipes that contain each ingredient
    recipes = df[df['diet'].str.contains(diet)]['recipe_title'].tolist()

    # If the number of recipes is less than n, we'll return all the recipes
    if len(recipes) < n:
        return recipes
    
    # We'll return n random recipes
    return random.sample(recipes, n)

# Let's try it out
get_random_diet_recipes('Vegetarian')
# Out:
# ['Whole Wheat Ravioli with Paneer & Creamy Mushroom Oat Sauce Recipe',
#  'Watermelon Bocconcini Arugula Salad Recipe',
#  'गाजर निम्बू चावल रेसिपी - Carrot Lemon Rice Recipe',
#  'Easy Sabudana Vada With Arrowroot Powder Recipe',
#  'Spiced Chutney Sandwich Recipe With Mint Mayo']

# %% [markdown]
# #### Get Random Recipes Based on Cuisine
# 5 random recipes based on given cuisine

# %%
# Let's write a function that will take a string of preferred diet and return 5 random recipes that fit that diet

# Find all nan values in the diet column
#print(df[df['cuisine'].isnull()])

# We'll need to replace the nan values with an Unknown string
df['cuisine'] = df['cuisine'].fillna('Unknown')

def get_random_cuisine_recipes(cuisine, n=5):

    # strip the cuisine of any leading or trailing spaces
    cuisine = cuisine.strip()

    # strip the cuisine of any leading or trailing " or ' characters
    cuisine = cuisine.strip('"')
    cuisine = cuisine.strip("'")

    # Capitalize the cuisine
    cuisine = cuisine.capitalize()

    # if the cuisine is not in cuisines column, we'll return "Sorry, we don't have any recipes for the given cuisine"
    if cuisine not in df['cuisine'].unique():
        return "Sorry, we don't have any recipes for the given cuisine!"

    # We'll get a list of all the recipes that contain each ingredient
    recipes = df[df['cuisine'].str.contains(cuisine)]['recipe_title'].tolist()

    # If the number of recipes is less than n, we'll return all the recipes
    if len(recipes) < n:
        return recipes
    
    # We'll return n random recipes
    return random.sample(recipes, n)

# Let's try it out
get_random_cuisine_recipes('Mediterranean')
# Out:
# ['Homemade Pita Bread Recipe - Quick and Simple Recipe',
#  'Pita Sandwich With Cauliflower Falafel And Roasted Vegetables Recipe',
#  'Egyptian Koshari Recipe',
#  'Mediterranean Cucumber Salad Recipe',
#  'Roasted Red Pepper Hummus Recipe ']

# %% [markdown]
# #### Recipe Search
# Get recipe explanation and ingredients based on recipe name

# %%
# Let's write a function that will take in a neme of a recipe and return ingredients, total_time, diet, cuisine, course and instructions

def get_recipe_info(recipe_name):
        
    # strip the recipe_name of any leading or trailing spaces
    recipe_name = recipe_name.strip()

    # strip the recipe_name of any leading or trailing " or ' characters
    recipe_name = recipe_name.strip('"')
    recipe_name = recipe_name.strip("'")

    # if the recipe_name is not in recipe_title column, we'll return "Sorry, we don't have any recipes for the given recipe name"
    if recipe_name not in df['recipe_title'].unique():
        return "Sorry, we don't have any recipes for the given recipe name!"
    
    # We'll find the row that is the recipe name using loc
    recipe = df.loc[df['recipe_title'].str.contains(recipe_name)]

    # We'll print out the information
    # print('Cuisine:', recipe['cuisine'].values[0])
    # print('Course:', recipe['course'].values[0])
    # print('Diet:', recipe['diet'].values[0])
    # print('Ingredients:', recipe['ingredients'].values[0])
    # print('Instructions:', recipe['instructions'].values[0])
    # print('Total Preparation Time:', recipe['total_time'].values[0])

    recipe = recipe[['cuisine', 'course', 'diet', 'ingredients', 'instructions', 'total_time']]

    # We'll return the recipe as a dictionary
    recipe = recipe.to_dict(orient='records')

    return recipe


# Let's try it out
get_recipe_info('Tzatziki Recipe')
# Out:
# Cuisine: Mediterranean
# Course: Side Dish
# Diet: Vegetarian
# Ingredients: Hung Curd (Greek Yogurt)|English Cucumber|Extra Virgin Olive Oil|Garlic|Parsley leaves|Black pepper powder|Salt
# Instructions: To begin making the Tzatziki, we will first remove all the whey from the yogurt. To do this we will hang the yogurt in a cloth sieve strainer, set over a bowl and kept in the refrigerator overnight.|You will notice that the whey has collected below and the yogurt is now thick and creamy.|Into a large mixing bowl, add in the thick hung yogurt ,you can also use Greek Yogurt as well.|To the bowl add the finely chopped cucumber, some minced garlic, minced parsley, chopped black olives, salt to taste, some freshly pounded black pepper, and not to miss the generous drizzle of olive oil. Stir well to combine.|Check the salt and flavors and adjust to suit your taste.|Transfer the Tzatziki to a serving dish place a sprig of parsley over the dip and sprinkle some smoked paprika or chilli powder. |You can now serve the Tzatziki (Greek Yogurt Dip) along with cucumbers, carrots and other vegetables like broccoli and even pineapple.|Serve the Tzatziki Recipe - A Greek Yogurt Dip as an appetizer dips along with | or | for Parties during a special occasion.
# Total Preparation Time: 25

# %% [markdown]
# ### Creating an Interactive Dashboard <a class = "anchor" id="creating_an_interactive_dashboard"></a>
# Now that we have analyzed the data, we can create an interactive dashboard to showcase our findings.
# We will use the Dashboard.py file to create the dashboard.

# %%
# Lets see the version of the all the libraries used in this project
import sys
print("Python version: {}".format(sys.version))

import pandas as pd
print("pandas version: {}".format(pd.__version__))
import bokeh
print("Bokeh version: {}".format(bokeh.__version__))
import numpy as np
print("NumPy version: {}".format(np.__version__))
import streamlit as st
print("Streamlit version: {}".format(st.__version__))
import requests
print("Requests version: {}".format(requests.__version__))
# Out:
# Python version: 3.10.8 (tags/v3.10.8:aaaf517, Oct 11 2022, 16:50:30) [MSC v.1933 64 bit (AMD64)]
# pandas version: 1.5.3
# Bokeh version: 2.4.3
# NumPy version: 1.24.2
# Streamlit version: 1.22.0
# Requests version: 2.28.1
